# %%
import os
import re
import pandas as pd
pd.options.display.max_colwidth = 20000
import nltk
import sklearn.feature_extraction.text
import spacy

# %%
pathName = r'C:\Users\agupt\Documents\Courses\MGTF 423'
fileName = 'McKesson10K2022.txt'
cleanFile = open(pathName +'\\'+ 'clean_' + fileName,'r')
content = cleanFile.read()

# %%
# A DataFrame for Text Data

lines = content.splitlines()
i = 0
j = 0
d = []
for l in lines:
    sent = re.split(r'\. |:',l)
    for s in sent:       
        d.append([i,j,s.strip()])
        j = j+1
    i = i+1
    j = 0
ldf = pd.DataFrame(d, columns = ['Line', 'Sent', 'Content'])
ldf
# Out:
#        Line  Sent  \
# 0         0     0
# 1         1     0
# 2         2     0
# 3         3     0
# 4         3     1
# ...     ...   ...
# 11425  8228     0
# 11426  8229     0
# 11427  8230     0
# 11428  8231     0
# 11429  8232     0
#
#                                                                                                                                                                                                                                                                                                 Content
# 0                                                                                                                                                                                                                                                                                     Table of Contents
# 1                                                                                                                                                                                                                                                                                         UNITED STATES
# 2                                                                                                                                                                                                                                                                    SECURITIES AND EXCHANGE COMMISSION
# 3                                                                                                                                                                                                                                                                                       Washington, D.C
# 4                                                                                                                                                                                                                                                                                                 20549
# ...                                                                                                                                                                                                                                                                                                 ...
# 11425                                                                                                                                                                                                                                                                                       May 9, 2022
# 11426
# 11427
# 11428  This certification accompanies the Report pursuant to § 906 of the Sarbanes-Oxley Act of 2002, and shall not, except to the extent required by the Sarbanes-Oxley Act of 2002, be deemed filed by the Company for the purposes of Section 18 of the Securities Exchange Act of 1934, as amended.
# 11429                                                              A signed original of this written statement required by Section 906 has been provided to McKesson Corporation and will be retained by the Company and furnished to the Securities and Exchange Commission or its staff upon request.
#
# [11430 rows x 3 columns]

# %%
nlp = spacy.load("en_core_web_trf")

# %%
# Finding parts of speech for tokens using Spacy

text = 'We are subject to the tax laws in the U.S. at the federal, state, and local government levels and to the tax laws of many other jurisdictions in which we operate or sell products or services. Tax laws might change in ways that adversely affect our tax positions, effective tax rate, and cash flow. The tax laws are extremely complex and subject to varying interpretations. We are subject to tax examinations in various jurisdictions that might assess additional tax liabilities against us. Our tax reporting positions might be challenged by relevant tax authorities, we might incur significant expense in our efforts to defend those challenges, and we might be unsuccessful in those efforts. Developments in examinations and challenges might materially change our provision for taxes in the affected periods and might differ materially from our historical tax accruals. Any of these risks might have a materially adverse impact on our business operations, our cash flows, and our financial position or results of operations'

doc = nlp(text)
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.is_stop)
# Out:
# C:\Users\agupt\anaconda3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# We we PRON True
# are be AUX True
# subject subject ADJ False
# to to ADP True
# the the DET True
# tax tax NOUN False
# laws law NOUN False
# in in ADP True
# the the DET True
# U.S. U.S. PROPN False
# at at ADP True
# the the DET True
# federal federal ADJ False
# , , PUNCT False
# state state NOUN False
# , , PUNCT False
# and and CCONJ True
# local local ADJ False
# government government NOUN False
# levels level NOUN False
# and and CCONJ True
# to to ADP True
# the the DET True
# tax tax NOUN False
# laws law NOUN False
# of of ADP True
# many many ADJ True
# other other ADJ True
# jurisdictions jurisdiction NOUN False
# in in ADP True
# which which PRON True
# we we PRON True
# operate operate VERB False
# or or CCONJ True
# sell sell VERB False
# products product NOUN False
# or or CCONJ True
# services service NOUN False
# . . PUNCT False
# Tax tax NOUN False
# laws law NOUN False
# might might AUX True
# change change VERB False
# in in ADP True
# ways way NOUN False
# that that PRON True
# adversely adversely ADV False
# affect affect VERB False
# our our PRON True
# tax tax NOUN False
# positions position NOUN False
# , , PUNCT False
# effective effective ADJ False
# tax tax NOUN False
# rate rate NOUN False
# , , PUNCT False
# and and CCONJ True
# cash cash NOUN False
# flow flow NOUN False
# . . PUNCT False
# The the DET True
# tax tax NOUN False
# laws law NOUN False
# are be AUX True
# extremely extremely ADV False
# complex complex ADJ False
# and and CCONJ True
# subject subject ADJ False
# to to ADP True
# varying vary VERB False
# interpretations interpretation NOUN False
# . . PUNCT False
# We we PRON True
# are be AUX True
# subject subject ADJ False
# to to ADP True
# tax tax NOUN False
# examinations examination NOUN False
# in in ADP True
# various various ADJ True
# jurisdictions jurisdiction NOUN False
# that that PRON True
# might might AUX True
# assess assess VERB False
# additional additional ADJ False
# tax tax NOUN False
# liabilities liability NOUN False
# against against ADP True
# us we PRON True
# . . PUNCT False
# Our our PRON True
# tax tax NOUN False
# reporting reporting NOUN False
# positions position NOUN False
# might might AUX True
# be be AUX True
# challenged challenge VERB False
# by by ADP True
# relevant relevant ADJ False
# tax tax NOUN False
# authorities authority NOUN False
# , , PUNCT False
# we we PRON True
# might might AUX True
# incur incur VERB False
# significant significant ADJ False
# expense expense NOUN False
# in in ADP True
# our our PRON True
# efforts effort NOUN False
# to to PART True
# defend defend VERB False
# those those DET True
# challenges challenge NOUN False
# , , PUNCT False
# and and CCONJ True
# we we PRON True
# might might AUX True
# be be AUX True
# unsuccessful unsuccessful ADJ False
# in in ADP True
# those those DET True
# efforts effort NOUN False
# . . PUNCT False
# Developments development NOUN False
# in in ADP True
# examinations examination NOUN False
# and and CCONJ True
# challenges challenge NOUN False
# might might AUX True
# materially materially ADV False
# change change VERB False
# our our PRON True
# provision provision NOUN False
# for for ADP True
# taxes taxis NOUN False
# in in ADP True
# the the DET True
# affected affected ADJ False
# periods period NOUN False
# and and CCONJ True
# might might AUX True
# differ differ VERB False
# materially materially ADV False
# from from ADP True
# our our PRON True
# historical historical ADJ False
# tax tax NOUN False
# accruals accrual NOUN False
# . . PUNCT False
# Any any PRON True
# of of ADP True
# these these DET True
# risks risk NOUN False
# might might AUX True
# have have VERB True
# a a DET True
# materially materially ADV False
# adverse adverse ADJ False
# impact impact NOUN False
# on on ADP True
# our our PRON True
# business business NOUN False
# operations operation NOUN False
# , , PUNCT False
# our our PRON True
# cash cash NOUN False
# flows flow NOUN False
# , , PUNCT False
# and and CCONJ True
# our our PRON True
# financial financial ADJ False
# position position NOUN False
# or or CCONJ True
# results result NOUN False
# of of ADP True
# operations operation NOUN False

# %%
# named entities

text = 'We are subject to the tax laws in the U.S. at the federal, state, and local government levels and to the tax laws of many other jurisdictions in which we operate or sell products or services. Tax laws might change in ways that adversely affect our tax positions, effective tax rate, and cash flow. The tax laws are extremely complex and subject to varying interpretations. We are subject to tax examinations in various jurisdictions that might assess additional tax liabilities against us. Our tax reporting positions might be challenged by relevant tax authorities, we might incur significant expense in our efforts to defend those challenges, and we might be unsuccessful in those efforts. Developments in examinations and challenges might materially change our provision for taxes in the affected periods and might differ materially from our historical tax accruals. Any of these risks might have a materially adverse impact on our business operations, our cash flows, and our financial position or results of operations'

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)

print('--------------')
s = 'This certification accompanies the Report pursuant to § 906 of the Sarbanes-Oxley Act of 2002, and shall not, except to the extent required by the Sarbanes-Oxley Act of 2002, be deemed filed by the Company for the purposes of Section 18 of the Securities Exchange Act of 1934, as amended.'
doc2 = nlp(s)
for ent in doc2.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# U.S. 38 42 GPE
# --------------
# § 906 of the Sarbanes-Oxley Act 54 85 LAW
# 2002 89 93 DATE
# the Sarbanes-Oxley Act 143 165 LAW
# 2002 169 173 DATE
# Company 198 205 ORG
# Section 18 of the Securities Exchange Act 226 267 LAW
# 1934 271 275 DATE

# %%
from spacy import displacy
#doc4 = nlp('Net income was $9.4 million compared to the prior year of $2.7 million')
displacy.render(doc2, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="258548d1f1df48118c3788bbfecbbe89-0" class="displacy" width="8975" height="924.5" direction="ltr" style="max-width: none; height: 924.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">certification</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">accompanies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">Report</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">pursuant</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">to §</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">906</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Sarbanes-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">Oxley</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Act</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">2002,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">shall</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">not,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">except</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">extent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">required</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">Sarbanes-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">Oxley</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">Act</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">2002,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor

# %%
# Finding a verb with a subject

from spacy.symbols import nsubj, VERB

verbs = set()
for possible_subject in doc2:
    if possible_subject.dep == nsubj and possible_subject.head.pos == VERB:
        verbs.add(possible_subject.head)
print(verbs)
# Out:
# {accompanies}

# %%
print([token.text for token in doc2[2].lefts])  
print([token.text for token in doc2[2].rights])  
print(doc2[2].n_lefts)  # 2
print(doc2[2].n_rights)  # 1
# Out:
# ['certification']
# ['Report', ',', 'and', 'deemed', '.']
# 1
# 5

# %%
root = [token for token in doc2 if token.head == token][0]
subject = list(root.lefts)[0]
print(subject)
print('-----------')
for descendant in subject.subtree:
    assert subject is descendant or subject.is_ancestor(descendant)
    print(descendant.text, descendant.dep_, descendant.n_lefts,
            descendant.n_rights,
            [ancestor.text for ancestor in descendant.ancestors])
# Out:
# certification
# -----------
# This det 0 0 ['certification', 'accompanies']
# certification nsubj 1 0 ['accompanies']

# %%
print(doc2[4])
print('--------------')
print(doc2[4].left_edge)
print('--------------')
print(doc2[4].right_edge)
print('--------------')
span = doc2[doc[4].left_edge.i : doc2[4].right_edge.i+1]
print(span)
print('--------------')
with doc2.retokenize() as retokenizer: 
    retokenizer.merge(span) # The retokenizer method will mark a span for merging.
for token in doc2:
    print(token.text, token.pos_, token.dep_, token.head.text)
# Out:
# Report pursuant to § 906 of the Sarbanes-Oxley Act of 2002
# --------------
# the
# --------------
# Report pursuant to § 906 of the Sarbanes-Oxley Act of 2002
# --------------
# Report pursuant to § 906 of the Sarbanes-Oxley Act of 2002
# --------------
# This DET det certification
# certification NOUN nsubj accompanies
# accompanies VERB ROOT accompanies
# the DET det Report pursuant to § 906 of the Sarbanes-Oxley Act of 2002
# Report pursuant to § 906 of the Sarbanes-Oxley Act of 2002 NOUN dobj accompanies
# , PUNCT punct accompanies
# and CCONJ cc accompanies
# shall AUX aux deemed
# not PART neg deemed
# , PUNCT punct deemed
# except SCONJ prep deemed
# to ADP prep except
# the DET det extent
# extent NOUN pobj to
# required VERB acl extent
# by ADP agent required
# the DET det Act
# Sarbanes PROPN compound Oxley
# - PUNCT punct Oxley
# Oxley PROPN compound Act
# Act PROPN pobj by
# of ADP prep Act
# 2002 NUM pobj of
# , PUNCT punct deemed
# be AUX auxpass deemed
# deemed VERB conj accompanies
# filed VERB xcomp deemed
# by ADP agent filed
# the DET det Company
# Company NOUN pobj by
# for ADP prep filed
# the DET det purposes
# purposes NOUN pobj for
# of ADP prep purposes
# Section NOUN pobj of
# 18 NUM nummod Section
# of ADP prep Section
# the DET det Act
# Securities PROPN compound Act
# Exchange PROPN compound Act
# Act PROPN pobj of
# of ADP prep Act
# 1934 NUM pobj of
# , PUNCT punct Section
# as SCONJ mark amended
# amended VERB advcl Section
# . PUNCT punct accompanies

# %%
nlp.add_pipe("merge_entities")
nlp.add_pipe("merge_noun_chunks")

TEXTS = [
    "Net income was $9.4 million compared to the prior year of $2.7 million.",
    "Revenue exceeded twelve billion dollars, with a loss of $1b.",
]
for doc in nlp.pipe(TEXTS):
    for token in doc:
        if token.ent_type_ == "MONEY":
            # We have an attribute and direct object, so check for subject
            if token.dep_ in ("attr", "dobj"):
                subj = [w for w in token.head.lefts if w.dep_ == "nsubj"]
                if subj:
                    print(subj[0], "-->", token)
            # We have a prepositional object with a preposition
            elif token.dep_ == "pobj" and token.head.dep_ == "prep":
                print(token.head.head, "-->", token)
# Out:
# Net income --> $9.4 million
# the prior year --> $2.7 million
# Revenue --> twelve billion dollars
# a loss --> $1b.

# %%
def get_subject_phrase(doc):
    for token in doc:
        if ("subj" in token.dep_):
            subtree = list(token.subtree)
            start = subtree[0].i
            end = subtree[-1].i + 1
            return doc[start:end]

# %%
def get_object_phrase(doc):
    for token in doc:
        if ("dobj" in token.dep_):
            subtree = list(token.subtree)
            start = subtree[0].i
            end = subtree[-1].i + 1
            return doc[start:end]

# %%
#getting subjects and objects
text = 'Revenue exceeded twelve billion dollars, with a loss of $1b'
doc3 = nlp(text)
subject_phrase = get_subject_phrase(doc3)
object_phrase = get_object_phrase(doc3)
print('subject phrase: ')
print(subject_phrase)
print('object phrase: ')
print(object_phrase)
# Out:
# subject phrase:
# Revenue
# object phrase:
# twelve billion dollars
