# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import spacy as sp
import fitz

# %%
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = ""

    for page_number in range(doc.page_count):
        page = doc[page_number]
        text += page.get_text()

    doc.close()
    return text

# %%
pdf_path = "C:\桌面\Desktop\Fluence 10k.pdf"
text = extract_text_from_pdf(pdf_path)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\25040\AppData\Local\Temp\ipykernel_9388\2298841862.py:1: SyntaxWarning: invalid escape sequence '\D'
#   pdf_path = "C:\桌面\Desktop\Fluence 10k.pdf"

# %%
npl= sp.load('en_core_web_sm')
doc= npl(text)

# %%
entities = [(ent.text, ent.label_) for ent in doc.ents]


df = pd.DataFrame(entities, columns=['Entity', 'Label'])
df=df.drop_duplicates()
org_df=df[df['Label'] == 'ORG']

# %%
from spacy.matcher import PhraseMatcher
matcher = PhraseMatcher(npl.vocab)
company_suffixes = ["Inc.", "Ltd.", "Corp.", "LLC", "PLC", "GmbH", "S.A.", "Pty Ltd",'Fluence Energy']
patterns = [npl.make_doc(text) for text in company_suffixes]
matcher.add("COMPANY", None, *patterns)

company_entities = []

for entity in org_df['Entity']:
    entity_doc = npl(entity)
    matches = matcher(entity_doc)
    if matches:
        company_entities.append(entity)

# 
company_df = pd.DataFrame(company_entities, columns=['Company'])
company_df
# Out:
#                                               Company
# 0                                Fluence Energy, Inc.
# 1                                      Fluence Energy
# 2                                                 LLC
# 3                  Organization\nFluence Energy, Inc.
# 4                              Siemens Industry, Inc.
# 5                              Fluence Energy, Inc.’s
# 6         Fluence Energy Global\nProduction Operation
# 7   Restated Limited Liability Company\nAgreement ...
# 8                                       LLC Interests
# 9   Amended and Restated Limited Liability Agreeme...
# 10                                the “Fluence Energy
# 11                                 the Fluence Energy
# 12                                      LLC Agreement
# 13                                       LLC Interest
# 14                           the Fluence Energy, Inc.
# 15                   the Fluence Energy LLC Agreement
# 16                    LLC Interests of Fluence Energy
# 17                                  Barclays Bank PLC
# 18         Fluence Energy Global Production Operation
# 19          the 2024 Credit Agreement, Fluence Energy
# 20                              Fluence\nEnergy, Inc.
# 21  the Board of Directors of Fluence Energy, Inc....
# 22  the Board of Directors of Fluence Energy, Inc....
# 23                                Fluence Energy GmbH
# 24                           Fluence Energy Pty\nLtd.
# 25                                Fluence Energy Inc.
# 26                           Fluence Energy Chile SpA
# 27                                Fluence Energy B.V.
# 28                                  Fluence Energy AG
# 29                             Fluence Energy UK Ltd.
# 30                          Fluence Energy Canada Inc
# 31                   Fluence Energy Singapore Pte Ltd
# 32                         Fluence Energy Taiwan Ltd.
# 33                     Fluence Energy Ireland Limited
# 34                 QFH’s Investment in Fluence Energy
# 35                          QIA Florence Holdings LLC
# 36  Amended and Restated Limited Liability\nCompan...
# 37                                  Qatar Holding LLC
# 38                       Fluence Energy Singapore PTE
# 39  Restated Certificate of Incorporation of Fluen...
# 40                    Incorporation of Fluence Energy
# 41       Class B-1 Common Stock\nFluence Energy, Inc.
# 42                                 Barclays Bank\nPLC
# 43  Global Paying Services Agreement between Fluen...
# 44                                 AES Services, Inc.
# 45                    The Fluence Energy Savings Plan
# 46                                 The Fluence Energy
# 47      the Fluence Energy Performance Interests Plan
# 48                       Organization\nFluence Energy
# 49  Delaware\nFluence Energy GmbH\nGermany\nFluenc...
# 50            Delaware\nFluence Energy Singapore Pte.
# 51                     Singapore\nFluence Energy Inc.
# 52                     Netherlands\nFluence Energy AG

# %%
relations = []
target_company = "Fluence Energy, Inc."

for sent in doc.sents:
    for company in company_df["Company"]:
        if company != target_company:
            if target_company in sent.text and company in sent.text:
                relations.append((target_company, company, sent.text.replace("\n", "")))

relations_df = pd.DataFrame(relations, columns=["Company1", "Company2", "Sentence"]).drop_duplicates(subset=["Company1", "Company2"])

# %%
relations_df['Company1'] = relations_df['Company1'].str.replace('\n', ' ')
relations_df['Company2'] = relations_df['Company2'].str.replace('\n', ' ')

# %%
relations_df
# Out:
#                  Company1                                           Company2  \
# 0    Fluence Energy, Inc.                                     Fluence Energy
# 2    Fluence Energy, Inc.                  Organization Fluence Energy, Inc.
# 3    Fluence Energy, Inc.                        Organization Fluence Energy
# 5    Fluence Energy, Inc.                                                LLC
# 12   Fluence Energy, Inc.                                      LLC Interests
# 13   Fluence Energy, Inc.                                       LLC Interest
# 15   Fluence Energy, Inc.                             Fluence Energy, Inc.’s
# 19   Fluence Energy, Inc.                                 the Fluence Energy
# 20   Fluence Energy, Inc.                           the Fluence Energy, Inc.
# 31   Fluence Energy, Inc.                             Siemens Industry, Inc.
# 33   Fluence Energy, Inc.                                      LLC Agreement
# 35   Fluence Energy, Inc.                    LLC Interests of Fluence Energy
# 61   Fluence Energy, Inc.                                  Barclays Bank PLC
# 65   Fluence Energy, Inc.         Fluence Energy Global Production Operation
# 97   Fluence Energy, Inc.  the Board of Directors of Fluence Energy, Inc....
# 101  Fluence Energy, Inc.  the Board of Directors of Fluence Energy, Inc....
# 124  Fluence Energy, Inc.  Amended and Restated Limited Liability Company...
# 125  Fluence Energy, Inc.                                  Qatar Holding LLC
# 158  Fluence Energy, Inc.                               Fluence Energy, Inc.
# 178  Fluence Energy, Inc.  Restated Certificate of Incorporation of Fluen...
# 179  Fluence Energy, Inc.                    Incorporation of Fluence Energy
# 180  Fluence Energy, Inc.        Class B-1 Common Stock Fluence Energy, Inc.
# 183  Fluence Energy, Inc.                                  Barclays Bank PLC
# 201  Fluence Energy, Inc.                                Fluence Energy GmbH
# 203  Fluence Energy, Inc.  Delaware Fluence Energy GmbH Germany Fluence E...
# 204  Fluence Energy, Inc.             Delaware Fluence Energy Singapore Pte.
# 209  Fluence Energy, Inc.                                Fluence Energy Inc.
# 210  Fluence Energy, Inc.                           Fluence Energy Chile SpA
# 211  Fluence Energy, Inc.                                Fluence Energy B.V.
# 212  Fluence Energy, Inc.                                  Fluence Energy AG
# 213  Fluence Energy, Inc.                          Fluence Energy Canada Inc
# 214  Fluence Energy, Inc.                         Fluence Energy Taiwan Ltd.
# 215  Fluence Energy, Inc.                     Fluence Energy Ireland Limited
# 216  Fluence Energy, Inc.                      Singapore Fluence Energy Inc.
# 217  Fluence Energy, Inc.                      Netherlands Fluence Energy AG
#
#                                               Sentence
# 0    For the transition period from toCommission fi...
# 2    3PART IITEM 1. BUSINESSInception and Organizat...
# 3    3PART IITEM 1. BUSINESSInception and Organizat...
# 5    As thesole managing member of Fluence Energy, ...
# 12   Current Ownership of Continuing Equity OwnersA...
# 13   Current Ownership of Continuing Equity OwnersA...
# 15   Therefore, the two Siemens entities collective...
# 19   Finally, we have reserved 9,500,000 shares of ...
# 20   Finally, we have reserved 9,500,000 shares of ...
# 31   On June 30, 2022, Siemens Industry, Inc. exerc...
# 33   On June 30, 2022, Siemens Industry, Inc. exerc...
# 35   On June 30, 2022, Siemens Industry, Inc. exerc...
# 61   On November 22, 2023, the Company entered into...
# 65   The ABL Facility was secured by (i) a first pr...
# 97   FINANCIAL STATEMENTS AND SUPPLEMENTARY DATAIND...
# 101  Tysons, VANovember 29, 202480Report of Indepen...
# 124  As the sole managing member of Fluence Energy,...
# 125  As the sole managing member of Fluence Energy,...
# 158  As of September 30, 2024, AES holds 51,499,195...
# 178  Incorporated by ReferenceExhibitNo.Exhibit Des...
# 179  Incorporated by ReferenceExhibitNo.Exhibit Des...
# 180  Incorporated by ReferenceExhibitNo.Exhibit Des...
# 183  8-K001-4097810.1November 27, 202310.36Master A...
# 201  * * * * *Updated: November 25, 202414\Exhibit ...
# 203  * * * * *Updated: November 25, 202414\Exhibit ...
# 204  * * * * *Updated: November 25, 202414\Exhibit ...
# 209  Ltd.SingaporeFluence Energy Inc.PhilippinesFlu...
# 210  Ltd.SingaporeFluence Energy Inc.PhilippinesFlu...
# 211  Ltd.SingaporeFluence Energy Inc.PhilippinesFlu...
# 212  Ltd.SingaporeFluence Energy Inc.PhilippinesFlu...
# 213  Ltd.SingaporeFluence Energy Inc.PhilippinesFlu...
# 214  Ltd.SingaporeFluence Energy Inc.PhilippinesFlu...
# 215  Ltd.SingaporeFluence Energy Inc.PhilippinesFlu...
# 216  Ltd.SingaporeFluence Energy Inc.PhilippinesFlu...
# 217  Ltd.SingaporeFluence Energy Inc.PhilippinesFlu...

# %%
import transformers
from transformers import pipeline

# %%
qa_pipeline = pipeline("question-answering")


question = "What is the relationship between Company1 and Company2?"


answers = []
for index, row in relations_df.iterrows():
    context = row['Sentence']
    answer = qa_pipeline(question=question, context=context)
    answers.append((row['Company1'], row['Company2'], answer['answer']))


answers_df = pd.DataFrame(answers, columns=['Company1', 'Company2', 'Answer'])

answers_df
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# WARNING:tensorflow:From d:\Python\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# Device set to use cpu
#                 Company1                                           Company2  \
# 0   Fluence Energy, Inc.                                     Fluence Energy
# 1   Fluence Energy, Inc.                  Organization Fluence Energy, Inc.
# 2   Fluence Energy, Inc.                        Organization Fluence Energy
# 3   Fluence Energy, Inc.                                                LLC
# 4   Fluence Energy, Inc.                                      LLC Interests
# 5   Fluence Energy, Inc.                                       LLC Interest
# 6   Fluence Energy, Inc.                             Fluence Energy, Inc.’s
# 7   Fluence Energy, Inc.                                 the Fluence Energy
# 8   Fluence Energy, Inc.                           the Fluence Energy, Inc.
# 9   Fluence Energy, Inc.                             Siemens Industry, Inc.
# 10  Fluence Energy, Inc.                                      LLC Agreement
# 11  Fluence Energy, Inc.                    LLC Interests of Fluence Energy
# 12  Fluence Energy, Inc.                                  Barclays Bank PLC
# 13  Fluence Energy, Inc.         Fluence Energy Global Production Operation
# 14  Fluence Energy, Inc.  the Board of Directors of Fluence Energy, Inc....
# 15  Fluence Energy, Inc.  the Board of Directors of Fluence Energy, Inc....
# 16  Fluence Energy, Inc.  Amended and Restated Limited Liability Company...
# 17  Fluence Energy, Inc.                                  Qatar Holding LLC
# 18  Fluence Energy, Inc.                               Fluence Energy, Inc.
# 19  Fluence Energy, Inc.  Restated Certificate of Incorporation of Fluen...
# 20  Fluence Energy, Inc.                    Incorporation of Fluence Energy
# 21  Fluence Energy, Inc.        Class B-1 Common Stock Fluence Energy, Inc.
# 22  Fluence Energy, Inc.                                  Barclays Bank PLC
# 23  Fluence Energy, Inc.                                Fluence Energy GmbH
# 24  Fluence Energy, Inc.  Delaware Fluence Energy GmbH Germany Fluence E...
# 25  Fluence Energy, Inc.             Delaware Fluence Energy Singapore Pte.
# 26  Fluence Energy, Inc.                                Fluence Energy Inc.
# 27  Fluence Energy, Inc.                           Fluence Energy Chile SpA
# 28  Fluence Energy, Inc.                                Fluence Energy B.V.
# 29  Fluence Energy, Inc.                                  Fluence Energy AG
# 30  Fluence Energy, Inc.                          Fluence Energy Canada Inc
# 31  Fluence Energy, Inc.                         Fluence Energy Taiwan Ltd.
# 32  Fluence Energy, Inc.                     Fluence Energy Ireland Limited
# 33  Fluence Energy, Inc.                      Singapore Fluence Energy Inc.
# 34  Fluence Energy, Inc.                      Netherlands Fluence Energy AG
#
#                                                Answer
# 0   State or other jurisdiction ofincorporation or...
# 1                                Delaware corporation
# 2                                Delaware corporation
# 3   operates and controls all the business and aff...
# 4                                  approximately28.5%
# 5                                  approximately28.5%
# 6                                unprecedented growth
# 7                           2021 Incentive Award Plan
# 8                           2021 Incentive Award Plan
# 9                        par value $0.00001 per share
# 10                       par value $0.00001 per share
# 11                       par value $0.00001 per share
# 12  revolving commitments in an aggregate principa...
# 13                customaryexceptions and limitations
# 14                                 September 30, 2024
# 15  internal control over financial reporting as o...
# 16                     exercised its redemption right
# 17                     exercised its redemption right
# 18                 Capital Contributions from Members
# 19                 Incorporated by ReferenceExhibitNo
# 20                 Incorporated by ReferenceExhibitNo
# 21                 Incorporated by ReferenceExhibitNo
# 22                      Syndicated Facility Agreement
# 23           LLCDelawareFluence Energy Singapore Pte.
# 24           LLCDelawareFluence Energy Singapore Pte.
# 25           LLCDelawareFluence Energy Singapore Pte.
# 26                             Registration Statement
# 27                             Registration Statement
# 28                             Registration Statement
# 29                             Registration Statement
# 30                             Registration Statement
# 31                             Registration Statement
# 32                             Registration Statement
# 33                             Registration Statement
# 34                             Registration Statement

# %%
answers_df['Company1'] = answers_df['Company1'].str.replace('\n', ' ')
answers_df['Company2'] = answers_df['Company2'].str.replace('\n', ' ')

answers_df=answers_df.drop_duplicates(subset=['Company1', 'Company2'])
answers_df
# Out:
#                 Company1                                           Company2  \
# 0   Fluence Energy, Inc.                                     Fluence Energy
# 1   Fluence Energy, Inc.                  Organization Fluence Energy, Inc.
# 2   Fluence Energy, Inc.                        Organization Fluence Energy
# 3   Fluence Energy, Inc.                                                LLC
# 4   Fluence Energy, Inc.                                      LLC Interests
# 5   Fluence Energy, Inc.                                       LLC Interest
# 6   Fluence Energy, Inc.                             Fluence Energy, Inc.’s
# 7   Fluence Energy, Inc.                                 the Fluence Energy
# 8   Fluence Energy, Inc.                           the Fluence Energy, Inc.
# 9   Fluence Energy, Inc.                             Siemens Industry, Inc.
# 10  Fluence Energy, Inc.                                      LLC Agreement
# 11  Fluence Energy, Inc.                    LLC Interests of Fluence Energy
# 12  Fluence Energy, Inc.                                  Barclays Bank PLC
# 13  Fluence Energy, Inc.         Fluence Energy Global Production Operation
# 14  Fluence Energy, Inc.  the Board of Directors of Fluence Energy, Inc....
# 15  Fluence Energy, Inc.  the Board of Directors of Fluence Energy, Inc....
# 16  Fluence Energy, Inc.  Amended and Restated Limited Liability Company...
# 17  Fluence Energy, Inc.                                  Qatar Holding LLC
# 18  Fluence Energy, Inc.                               Fluence Energy, Inc.
# 19  Fluence Energy, Inc.  Restated Certificate of Incorporation of Fluen...
# 20  Fluence Energy, Inc.                    Incorporation of Fluence Energy
# 21  Fluence Energy, Inc.        Class B-1 Common Stock Fluence Energy, Inc.
# 23  Fluence Energy, Inc.                                Fluence Energy GmbH
# 24  Fluence Energy, Inc.  Delaware Fluence Energy GmbH Germany Fluence E...
# 25  Fluence Energy, Inc.             Delaware Fluence Energy Singapore Pte.
# 26  Fluence Energy, Inc.                                Fluence Energy Inc.
# 27  Fluence Energy, Inc.                           Fluence Energy Chile SpA
# 28  Fluence Energy, Inc.                                Fluence Energy B.V.
# 29  Fluence Energy, Inc.                                  Fluence Energy AG
# 30  Fluence Energy, Inc.                          Fluence Energy Canada Inc
# 31  Fluence Energy, Inc.                         Fluence Energy Taiwan Ltd.
# 32  Fluence Energy, Inc.                     Fluence Energy Ireland Limited
# 33  Fluence Energy, Inc.                      Singapore Fluence Energy Inc.
# 34  Fluence Energy, Inc.                      Netherlands Fluence Energy AG
#
#                                                Answer
# 0   State or other jurisdiction ofincorporation or...
# 1                                Delaware corporation
# 2                                Delaware corporation
# 3   operates and controls all the business and aff...
# 4                                  approximately28.5%
# 5                                  approximately28.5%
# 6                                unprecedented growth
# 7                           2021 Incentive Award Plan
# 8                           2021 Incentive Award Plan
# 9                        par value $0.00001 per share
# 10                       par value $0.00001 per share
# 11                       par value $0.00001 per share
# 12  revolving commitments in an aggregate principa...
# 13                customaryexceptions and limitations
# 14                                 September 30, 2024
# 15  internal control over financial reporting as o...
# 16                     exercised its redemption right
# 17                     exercised its redemption right
# 18                 Capital Contributions from Members
# 19                 Incorporated by ReferenceExhibitNo
# 20                 Incorporated by ReferenceExhibitNo
# 21                 Incorporated by ReferenceExhibitNo
# 23           LLCDelawareFluence Energy Singapore Pte.
# 24           LLCDelawareFluence Energy Singapore Pte.
# 25           LLCDelawareFluence Energy Singapore Pte.
# 26                             Registration Statement
# 27                             Registration Statement
# 28                             Registration Statement
# 29                             Registration Statement
# 30                             Registration Statement
# 31                             Registration Statement
# 32                             Registration Statement
# 33                             Registration Statement
# 34                             Registration Statement
